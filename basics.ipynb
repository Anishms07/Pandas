# %%
import yfinance as yf

# Fetching data using yfinance
df = yf.download('AAPL', start='2023-01-01', end='2023-08-01')

# Display the data table
print(df)
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-01-03  130.279999  130.899994  124.169998  125.070000  124.706833
# 2023-01-04  126.889999  128.660004  125.080002  126.360001  125.993095
# 2023-01-05  127.129997  127.769997  124.760002  125.019997  124.656982
# 2023-01-06  126.010002  130.289993  124.889999  129.619995  129.243622
# 2023-01-09  130.470001  133.410004  129.889999  130.149994  129.772079
# ...                ...         ...         ...         ...         ...
# 2023-07-25  193.330002  194.440002  192.919998  193.619995  193.619995
# 2023-07-26  193.669998  195.639999  193.320007  194.500000  194.500000
# 2023-07-27  196.020004  197.199997  192.550003  193.220001  193.220001
# 2023-07-28  194.669998  196.630005  194.139999  195.830002  195.830002
# 2023-07-31  196.059998  196.490005  195.259995  196.449997  196.449997
#
#                Volume
# Date
# ...

# %%
# %matplotlib inline
df.plot(y="Close",color="Green")
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot.bar(y="Volume")
# Out:
# <Axes: xlabel='Date'>

# %%
# %%html
# <iframe width="560" height="315" src="https://www.youtube.com/embed/EEEZX_0FMEc" frameborder="0" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/EEEZX_0FMEc" frameborder="0" allowfullscreen></iframe>

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %colors  %conda  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %matplotlib  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %%
# %time for i in range(2000000): i*i
# Out:
# CPU times: total: 234 ms
# Wall time: 482 ms

# %%
# %system dir
# Out:
# [' Volume in drive C is Windows',
#  ' Volume Serial Number is 0066-DF6F',
#  '',
#  ' Directory of C:\\Users\\ANISH M S\\Untitled Folder',
#  '',
#  '08-08-2023  11:36    <DIR>          .',
#  '08-08-2023  11:19    <DIR>          ..',
#  '08-08-2023  11:04    <DIR>          .ipynb_checkpoints',
#  '08-08-2023  11:36            46,815 Untitled.ipynb',
#  '               1 File(s)         46,815 bytes',
#  '               3 Dir(s)  104,479,076,352 bytes free']

# %%
import pandas as pd

# Use double backslashes or a raw string for the file path
file_path = 'C:\\Users\\ANISH M S\\Downloads\\annual-enterprise-survey-2021-financial-year-provisional-csv.csv'

df = pd.read_csv(file_path)
print(df)



annual-enterprise-survey-2021-financial-year-provisional-csv
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2021                     Level 1                99999
# 1      2021                     Level 1                99999
# 2      2021                     Level 1                99999
# 3      2021                     Level 1                99999
# 4      2021                     Level 1                99999
# ...     ...                         ...                  ...
# 41710  2013                     Level 3                 ZZ11
# 41711  2013                     Level 3                 ZZ11
# 41712  2013                     Level 3                 ZZ11
# 41713  2013                     Level 3                 ZZ11
# 41714  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
import pandas as pd

file_path = 'C:\\Users\\ANISH M S\\Downloads\\annual-enterprise-survey-2021-financial-year-provisional-csv.csv'
# Alternatively, you can use a raw string
# file_path = r'C:\Users\ANISH M S\Downloads\annual-enterprise-survey-2021-financial-year-provisional-csv.csv'

df = pd.read_csv(file_path)
print(df)
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2021                     Level 1                99999
# 1      2021                     Level 1                99999
# 2      2021                     Level 1                99999
# 3      2021                     Level 1                99999
# 4      2021                     Level 1                99999
# ...     ...                         ...                  ...
# 41710  2013                     Level 3                 ZZ11
# 41711  2013                     Level 3                 ZZ11
# 41712  2013                     Level 3                 ZZ11
# 41713  2013                     Level 3                 ZZ11
# 41714  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
df.columns
# Out:
# Index(['Year', 'Industry_aggregation_NZSIOC', 'Industry_code_NZSIOC',
#        'Industry_name_NZSIOC', 'Units', 'Variable_code', 'Variable_name',
#        'Variable_category', 'Value', 'Industry_code_ANZSIC06'],
#       dtype='object')

# %%
df['Industry_aggregation_NZSIOC']
# Out:
# 0        Level 1
# 1        Level 1
# 2        Level 1
# 3        Level 1
# 4        Level 1
#           ...
# 41710    Level 3
# 41711    Level 3
# 41712    Level 3
# 41713    Level 3
# 41714    Level 3
# Name: Industry_aggregation_NZSIOC, Length: 41715, dtype: object

# %%
df['Industry_code_NZSIOC']
# Out:
# 0        99999
# 1        99999
# 2        99999
# 3        99999
# 4        99999
#          ...
# 41710     ZZ11
# 41711     ZZ11
# 41712     ZZ11
# 41713     ZZ11
# 41714     ZZ11
# Name: Industry_code_NZSIOC, Length: 41715, dtype: object
