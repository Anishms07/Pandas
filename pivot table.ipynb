# %%
import pandas as pd
from tabulate import tabulate
df=pd.read_csv("C:\\Users\\ANISH M S\\Downloads\\weather (1).csv")

# %%
print(tabulate(df,headers="keys",tablefmt="grid"))
# Out:
# +----+----------+----------+---------------+------------+
# |    | date     | city     |   temperature |   humidity |
# +====+==========+==========+===============+============+
# |  0 | 5/1/2017 | new york |            65 |         56 |
# +----+----------+----------+---------------+------------+
# |  1 | 5/2/2017 | new york |            66 |         58 |
# +----+----------+----------+---------------+------------+
# |  2 | 5/3/2017 | new york |            68 |         60 |
# +----+----------+----------+---------------+------------+
# |  3 | 5/1/2017 | mumbai   |            75 |         80 |
# +----+----------+----------+---------------+------------+
# |  4 | 5/2/2017 | mumbai   |            78 |         83 |
# +----+----------+----------+---------------+------------+
# |  5 | 5/3/2017 | mumbai   |            82 |         85 |
# +----+----------+----------+---------------+------------+
# |  6 | 5/1/2017 | beijing  |            80 |         26 |
# ...

# %%
df.pivot(index="date",columns="city")
# Out:
#          temperature                 humidity
# city         beijing mumbai new york  beijing mumbai new york
# date
# 5/1/2017          80     75       65       26     80       56
# 5/2/2017          77     78       66       30     83       58
# 5/3/2017          79     82       68       35     85       60

# %%
df.pivot(index="date",columns="city",values="humidity")
# Out:
# city      beijing  mumbai  new york
# date
# 5/1/2017       26      80        56
# 5/2/2017       30      83        58
# 5/3/2017       35      85        60

# %%
df1=pd.read_csv("C:\\Users\\ANISH M S\\Downloads\\weather2.csv")

# %%
df1
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/1/2017  new york           61        54
# 2  5/2/2017  new york           70        60
# 3  5/2/2017  new york           72        62
# 4  5/1/2017    mumbai           75        80
# 5  5/1/2017    mumbai           78        83
# 6  5/2/2017    mumbai           82        85
# 7  5/2/2017    mumbai           80        26

# %%
#now here you can see that new york has more than 1 temps and humidity on a same day, so by using pivot table we can take a avg and make one

# %%
df1.pivot_table(index="city",columns="date")#here it took the average
# Out:
#          humidity          temperature
# date     5/1/2017 5/2/2017    5/1/2017 5/2/2017
# city
# mumbai       81.5     55.5        76.5     81.0
# new york     55.0     61.0        63.0     71.0

# %%
df1.pivot_table(index="city",columns=["humidity","temperature"])
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\groupby\groupby.py:1490, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1489 try:
# -> 1490     result = self.grouper._cython_operation(
#    1491         "aggregate",
#    1492         values,
#    1493         how,
#    1494         axis=data.ndim - 1,
#    1495         min_count=min_count,
#    1496         **kwargs,
#    1497     )
#    1498 except NotImplementedError:
#    1499     # generally if we have numeric_only=False
#    1500     # and non-applicable functions
#    1501     # try to python agg
#    1502     # TODO: shouldn't min_count matter?
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\groupby\ops.py:959, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
# ...

# %%
df1.pivot_table(index="city",columns="date",aggfunc="sum")#here it took the sum
# Out:
#          humidity          temperature
# date     5/1/2017 5/2/2017    5/1/2017 5/2/2017
# city
# mumbai        163      111         153      162
# new york      110      122         126      142

# %%
 df1.pivot_table(index="city",columns="date",aggfunc="count")
# Out:
#          humidity          temperature
# date     5/1/2017 5/2/2017    5/1/2017 5/2/2017
# city
# mumbai          2        2           2        2
# new york        2        2           2        2

# %%
df3=pd.read_csv("C:\\Users\\ANISH M S\\Downloads\\weather3.csv")

# %%
df3
# Out:
#         date      city  temperature  humidity
# 0   5/1/2017  new york           65        56
# 1   5/2/2017  new york           61        54
# 2   5/3/2017  new york           70        60
# 3  12/1/2017  new york           30        50
# 4  12/2/2017  new york           28        52
# 5  12/3/2017  new york           25        51

# %%
type(df3.date[0])
# Out:
# str

# %%
df3['date']=pd.to_datetime(df3['date'])

# %%
type(df3.date[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df3.pivot_table(index=pd.Grouper(freq='M',key='date'),columns='city')
# Out:
#              humidity temperature
# city         new york    new york
# date
# 2017-05-31  56.666667   65.333333
# 2017-12-31  51.000000   27.666667

# %%
df3.pivot_table(index='date',columns='city')
# Out:
#            humidity temperature
# city       new york    new york
# date
# 2017-05-01       56          65
# 2017-05-02       54          61
# 2017-05-03       60          70
# 2017-12-01       50          30
# 2017-12-02       52          28
# 2017-12-03       51          25

# %%
df1
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/1/2017  new york           61        54
# 2  5/2/2017  new york           70        60
# 3  5/2/2017  new york           72        62
# 4  5/1/2017    mumbai           75        80
# 5  5/1/2017    mumbai           78        83
# 6  5/2/2017    mumbai           82        85
# 7  5/2/2017    mumbai           80        26

# %%
#next are just my experiment in learning

# %%
exp=df1.pivot_table(index='date',columns='city')

# %%
df1
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/1/2017  new york           61        54
# 2  5/2/2017  new york           70        60
# 3  5/2/2017  new york           72        62
# 4  5/1/2017    mumbai           75        80
# 5  5/1/2017    mumbai           78        83
# 6  5/2/2017    mumbai           82        85
# 7  5/2/2017    mumbai           80        26

# %%
exp
# Out:
#          humidity          temperature
# city       mumbai new york      mumbai new york
# date
# 5/1/2017     81.5     55.0        76.5     63.0
# 5/2/2017     55.5     61.0        81.0     71.0

# %%
exp.stack()
# Out:
#                    humidity  temperature
# date     city
# 5/1/2017 mumbai        81.5         76.5
#          new york      55.0         63.0
# 5/2/2017 mumbai        55.5         81.0
#          new york      61.0         71.0
