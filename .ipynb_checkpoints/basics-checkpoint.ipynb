# %%
import pandas.io.data as web
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import pandas.io.data as web
#
# ModuleNotFoundError: No module named 'pandas.io.data'

# %%
import pandas_datareader as pdr


df = pdr.get_data_yahoo('AAPL', start='2023-01-01', end='2023-08-01')
print(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       1 import pandas_datareader as pdr
# ----> 4 df = pdr.get_data_yahoo('AAPL', start='2023-01-01', end='2023-08-01')
#       5 print(df)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas_datareader\data.py:80, in get_data_yahoo(*args, **kwargs)
#      79 def get_data_yahoo(*args, **kwargs):
# ---> 80     return YahooDailyReader(*args, **kwargs).read()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas_datareader\base.py:253, in _DailyBaseReader.read(self)
#     251 # If a single symbol, (e.g., 'GOOG')
#     252 if isinstance(self.symbols, (string_types, int)):
# --> 253     df = self._read_one_data(self.url, params=self._get_params(self.symbols))
#     254 # Or multiple symbols, (e.g., ['GOOG', 'AAPL', 'MSFT'])
#     255 elif isinstance(self.symbols, DataFrame):
#
# ...

# %%
import pandas_datareader as pdr

# Import DataReader from pandas_datareader.data
from pandas_datareader import data as web

# Fetching data from Yahoo Finance
df = web.DataReader('AAPL', data_source='yahoo', start='2023-01-01', end='2023-08-01')

# Display the data table
print(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 7
#       4 from pandas_datareader import data as web
#       6 # Fetching data from Yahoo Finance
# ----> 7 df = web.DataReader('AAPL', data_source='yahoo', start='2023-01-01', end='2023-08-01')
#       9 # Display the data table
#      10 print(df)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\util\_decorators.py:210, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     208         raise TypeError(msg)
#     209     kwargs[new_arg_name] = new_arg_value
# --> 210 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas_datareader\data.py:379, in DataReader(name, data_source, start, end, retry_count, pause, session, api_key)
#     367     raise NotImplementedError(msg)
#     369 if data_source == "yahoo":
# ...

# %%
import pandas_datareader as pdr

# Import DataReader from pandas_datareader.data
from pandas_datareader import data as web

# Fetching data from Alpha Vantage
# Note: You need to replace 'YOUR_API_KEY' with your actual Alpha Vantage API key
df = web.DataReader('AAPL', data_source='av', start='2023-01-01', end='2023-08-01', api_key='6Q8OSLTOYINO0OHF')

# Display the data table
print(df)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[6], line 8
#       4 from pandas_datareader import data as web
#       6 # Fetching data from Alpha Vantage
#       7 # Note: You need to replace 'YOUR_API_KEY' with your actual Alpha Vantage API key
# ----> 8 df = web.DataReader('AAPL', data_source='av', start='2023-01-01', end='2023-08-01', api_key='6Q8OSLTOYINO0OHF')
#      10 # Display the data table
#      11 print(df)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\util\_decorators.py:210, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     208         raise TypeError(msg)
#     209     kwargs[new_arg_name] = new_arg_value
# --> 210 return func(*args, **kwargs)
#
# ...

# %%
import yfinance as yf

# Fetching data using yfinance
df = yf.download('AAPL', start='2023-01-01', end='2023-08-01')

# Display the data table
print(df)
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-01-03  130.279999  130.899994  124.169998  125.070000  124.706833
# 2023-01-04  126.889999  128.660004  125.080002  126.360001  125.993095
# 2023-01-05  127.129997  127.769997  124.760002  125.019997  124.656982
# 2023-01-06  126.010002  130.289993  124.889999  129.619995  129.243622
# 2023-01-09  130.470001  133.410004  129.889999  130.149994  129.772079
# ...                ...         ...         ...         ...         ...
# 2023-07-25  193.330002  194.440002  192.919998  193.619995  193.619995
# 2023-07-26  193.669998  195.639999  193.320007  194.500000  194.500000
# 2023-07-27  196.020004  197.199997  192.550003  193.220001  193.220001
# 2023-07-28  194.669998  196.630005  194.139999  195.830002  195.830002
# 2023-07-31  196.059998  196.490005  195.259995  196.449997  196.449997
#
#                Volume
# Date
# ...

# %%
# %matplotlib inline
df.plot(y="Close",color="Green")
# Out:
# <Axes: xlabel='Date'>
