# %%
import pandas as pd
import sqlalchemy

# %%
engine=sqlalchemy.create_engine('mysql+pymysql://root:anishms666@localhost:3306/db')

# %%
df=pd.read_sql_table("movie",engine) #you can include columns parameter here to get only specified cols

# %%
df
# Out:
#     id                 title  year_of_release  runtime  imdb_rating
# 0    1                jersey             2019      160          8.6
# 1    2                  eega             2012      147          7.7
# 2    3             baahubali             2015      160          8.0
# 3    4                 saaho             2019      157          5.2
# 4    5                  arya             2004      165          7.8
# 5    6            sarrainodu             2016      162          6.5
# 6    7        janatha garage             2016      162          7.3
# 7    8      nannaku prematho             2016      168          7.6
# 8    9                yevadu             2014      165          5.7
# 9   10             yuvaratna             2021      160          6.6
# 10  11             rajkumara             2017      148          8.0
# 11  12        kasturi nivasa             1971      160          8.4
# 12  13             aakasmika             1993      146          7.1
# ...

# %%
query="select * from movie where runtime>150;"
df1=pd.read_sql_query(query,engine)
df1
# Out:
#     id                 title  year_of_release  runtime  imdb_rating
# 0    1                jersey             2019      160          8.6
# 1    3             baahubali             2015      160          8.0
# 2    4                 saaho             2019      157          5.2
# 3    5                  arya             2004      165          7.8
# 4    6            sarrainodu             2016      162          6.5
# 5    7        janatha garage             2016      162          7.3
# 6    8      nannaku prematho             2016      168          7.6
# 7    9                yevadu             2014      165          5.7
# 8   10             yuvaratna             2021      160          6.6
# 9   12        kasturi nivasa             1971      160          8.4
# 10  14           kirik party             2016      165          8.4
# 11  15  avane srimannarayana             2019      180          7.9
# 12  18                 mufti             2017      160          8.0
# ...
